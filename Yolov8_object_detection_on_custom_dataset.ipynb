# %%
# !nvidia-smi
# Out:
# 'nvidia-smi' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# D:\Food_Images.v1i.yolov8

# %% [markdown]
# ## Install YOLOv8
#
# ⚠️ YOLOv8 is still under heavy development. Breaking changes are being introduced almost weekly. We strive to make our YOLOv8 notebooks work with the latest version of the library. Last tests took place on **18.01.2023** with version **YOLOv8.0.9**.
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# YOLOv8 can be installed in two ways - from the source and via pip. This is because it is the first iteration of YOLO to have an official package.

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.58  Python-3.11.9 torch-2.2.2+cpu CPU
# Setup complete  (4 CPUs, 15.4 GB RAM, 113.9/319.3 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://v8docs.ultralytics.com/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %%
# !pip install pickleshare
# !pip install ipython

# %%
# %cd D:\Food_Images.v1i.yolov8
# Out:
# D:\Food_Images.v1i.yolov8

# %%
ls
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is 8835-C4A4
#
#  Directory of D:\Food_Images.v1i.yolov8
#
# 07/04/2024  18:46    <DIR>          .
# 08/04/2024  17:17             1,083 data.yaml
# 07/04/2024  18:46    <DIR>          runs
# 07/04/2024  13:25    <DIR>          test
# 07/04/2024  18:14    <DIR>          train
# 07/04/2024  18:14    <DIR>          valid
# 07/04/2024  18:46        22,573,363 yolov8s.pt
#                2 File(s)     22,574,446 bytes
#                5 Dir(s)  174,738,182,144 bytes free

# %%
# %cd D:\Food_Images.v1i.yolov8

# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=25 imgsz=224 plots=True
# Out:
# D:\Food_Images.v1i.yolov8
# ...
# Ultralytics YOLOv8.1.44 🚀 Python-3.11.9 torch-2.2.2+cpu CPU (Intel Core(TM) i5-7200U 2.50GHz)
# ...

# %%
# !ls runs/detect/train/
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from IPython.display import Image
Image(filename='runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename='runs/detect/train/results.png', width=600)

# %%
Image(filename='runs/detect/train/val_batch0_pred.jpg', width=600)

# %%
# !yolo task=detect mode=val model='D:\Food_Images.v1i.yolov8\\runs\detect\\train\weights' data=data.yaml
# from ultralytics import YOLO
# model=YOLO(r'D:\Food_Images.v1i.yolov8\\runs\detect\\train\weights')
# result=model.predict(r"c:\Users\Admin\Desktop\nutrascan\Images_yolo\images\0b84f41ca9_jpg.rf.9e68042ccb753c338f2eadd1ab36e689.jpg")
# Out:
# Ultralytics YOLOv8.1.44 🚀 Python-3.11.9 torch-2.2.2+cpu CPU (Intel Core(TM) i5-7200U 2.50GHz)
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\cfg\__init__.py", line 582, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\engine\model.py", line 527, in val
#     validator(model=self.model)
# ...

# %% [markdown]
# ## Inference with Custom Model

# %%
# !yolo task=detect mode=predict model=r"D:\Food_Images.v1i.yolov8\runs\detect\train\weights\best.pt"conf=0.25 source=data/test/images
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\cfg\__init__.py", line 555, in entrypoint
#     model = YOLO(model, task=task)
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\models\yolo\model.py", line 23, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
# ...
